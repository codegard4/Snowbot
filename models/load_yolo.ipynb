# %%
from ultralytics import YOLO

# Load a pre-trained YOLOv8n model
model = YOLO('yolov8n.pt')
# Out:
# Creating new Ultralytics Settings v0.0.6 file
# View Ultralytics Settings with 'yolo settings' or at 'C:\Users\coleo\AppData\Roaming\Ultralytics\settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolov8n.pt to 'yolov8n.pt'...
# 100%|██████████| 6.25M/6.25M [00:00<00:00, 8.99MB/s]
# Ultralytics 8.3.94  Python-3.9.13 torch-2.6.0+cpu CPU (Intel Core(TM) i9-10885H 2.40GHz)
# YOLOv8n summary (fused): 72 layers, 3,151,904 parameters, 0 gradients, 8.7 GFLOPs
#
# PyTorch: starting from 'yolov8n.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 84, 8400) (6.2 MB)
# requirements: Ultralytics requirements ['onnx>=1.12.0', 'onnxslim', 'onnxruntime'] not found, attempting AutoUpdate...
# requirements:  AutoUpdate skipped (offline)
# ONNX: export failure  0.0s: No module named 'onnx'
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 7
#       4 model = YOLO('yolov8n.pt')
#       6 # Export the model to ONNX format
# ----> 7 model.export(format='onnx')
#
# File ~\anaconda3\lib\site-packages\ultralytics\engine\model.py:728, in Model.export(self, **kwargs)
#     720 custom = {
#     721     "imgsz": self.model.args["imgsz"],
#     722     "batch": 1,
#    (...)
#     725     "verbose": False,
#     726 }  # method defaults
#     727 args = {**self.overrides, **custom, **kwargs, "mode": "export"}  # highest priority args on the right
# --> 728 return Exporter(overrides=args, _callbacks=self.callbacks)(model=self.model)
#
# File ~\anaconda3\lib\site-packages\ultralytics\engine\exporter.py:433, in Exporter.__call__(self, model)
#     431     f[1], _ = self.export_engine(dla=dla)
#     432 if onnx:  # ONNX
# --> 433     f[2], _ = self.export_onnx()
#     434 if xml:  # OpenVINO
#     435     f[3], _ = self.export_openvino()
#
# File ~\anaconda3\lib\site-packages\ultralytics\engine\exporter.py:181, in try_export.<locals>.outer_func(*args, **kwargs)
#     179 except Exception as e:
#     180     LOGGER.error(f"{prefix} export failure ❌ {dt.t:.1f}s: {e}")
# --> 181     raise e
#
# File ~\anaconda3\lib\site-packages\ultralytics\engine\exporter.py:176, in try_export.<locals>.outer_func(*args, **kwargs)
#     174 try:
#     175     with Profile() as dt:
# --> 176         f, model = inner_func(*args, **kwargs)
#     177     LOGGER.info(f"{prefix} export success ✅ {dt.t:.1f}s, saved as '{f}' ({file_size(f):.1f} MB)")
#     178     return f, model
#
# File ~\anaconda3\lib\site-packages\ultralytics\engine\exporter.py:533, in Exporter.export_onnx(self, prefix)
#     531     requirements += ["onnxslim", "onnxruntime" + ("-gpu" if torch.cuda.is_available() else "")]
#     532 check_requirements(requirements)
# --> 533 import onnx  # noqa
#     535 opset_version = self.args.opset or get_latest_opset()
#     536 LOGGER.info(f"\n{prefix} starting export with onnx {onnx.__version__} opset {opset_version}...")
#
# ModuleNotFoundError: No module named 'onnx'

# %%
# Export the model to ONNX format
model.export(format='onnx')
# Out:
# Ultralytics 8.3.94  Python-3.9.13 torch-2.6.0+cpu CPU (Intel Core(TM) i9-10885H 2.40GHz)
# YOLOv8n summary (fused): 72 layers, 3,151,904 parameters, 0 gradients, 8.7 GFLOPs
#
# PyTorch: starting from 'yolov8n.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 84, 8400) (6.2 MB)
# requirements: Ultralytics requirement ['onnxslim'] not found, attempting AutoUpdate...
# requirements:  AutoUpdate skipped (offline)
#
# ONNX: starting export with onnx 1.17.0 opset 19...
# ONNX: simplifier failure: No module named 'onnxslim'
# ONNX: export success  0.7s, saved as 'yolov8n.onnx' (12.2 MB)
#
# Export complete (1.2s)
# Results saved to C:\Users\coleo\PycharmProjects\ObjectDetection\Snowbot\imageModificationNotebooks
# Predict:         yolo predict task=detect model=yolov8n.onnx imgsz=640
# Validate:        yolo val task=detect model=yolov8n.onnx imgsz=640 data=coco.yaml
# Visualize:       https://netron.app
# 'yolov8n.onnx'
